# %%
file=open("data.csv","x")
file.close()
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 file=open("data.csv","x")
#       2 file.close()
#
# File C:\ProgramData\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileExistsError: [Errno 17] File exists: 'data.csv'

# %%
import pandas as pd
df=pd.read_csv('data.csv')
df
# Out:
#    sn   name  age        add     phone
# 0   1    Ram   23  Kathmandu  98442789
# 1   2  Shyam   44  Bhaktapur    789654
# 2   3   Hari   33   Janakpur    980654
# 3   4  Nabin   66  Kathmandu    897654
# 4   5  Akash   23  Bhaktapur    980765
# 5   6  Nabin   32      Jhapa   9876500

# %%
import pandas as pd
df=pd.read_csv('data.csv')
df.head(3)
# Out:
#    sn   name  age        add     phone
# 0   1    Ram   23  Kathmandu  98442789
# 1   2  Shyam   44  Bhaktapur    789654
# 2   3   Hari   33   Janakpur    980654

# %%
import pandas as pd
df=pd.read_csv('data.csv')
df.tail(3)
# Out:
#    sn   name  age        add    phone
# 3   4  Nabin   66  Kathmandu   897654
# 4   5  Akash   23  Bhaktapur   980765
# 5   6  Nabin   32      Jhapa  9876500

# %%
import pandas as pd
df=pd.read_csv('data.csv',index_col="sn")
df
# Out:
#      name  age        add     phone
# sn
# 1     Ram   23  Kathmandu  98442789
# 2   Shyam   44  Bhaktapur    789654
# 3    Hari   33   Janakpur    980654
# 4   Nabin   66  Kathmandu    897654
# 5   Akash   23  Bhaktapur    980765
# 6   Nabin   32      Jhapa   9876500

# %%
import pandas as pd
df=pd.read_csv('data.csv',index_col="sn",usecols=["sn","name","phone"])
df
# Out:
#      name     phone
# sn
# 1     Ram  98442789
# 2   Shyam    789654
# 3    Hari    980654
# 4   Nabin    897654
# 5   Akash    980765
# 6   Nabin   9876500

# %%
import pandas as pd
df=pd.read_csv('data.csv',index_col="sn")
df.iloc[0]
# Out:
# name           Ram
# age             23
# add      Kathmandu
# phone     98442789
# Name: 1, dtype: object

# %%
import pandas as pd
df=pd.read_csv('data.csv',index_col="sn")
df.iloc[2:5]
# Out:
#      name  age        add   phone
# sn
# 3    Hari   33   Janakpur  980654
# 4   Nabin   66  Kathmandu  897654
# 5   Akash   23  Bhaktapur  980765

# %%
import pandas as pd
df=pd.read_csv('data.csv',index_col="sn")
df.iloc[2:5,0:3]
# Out:
#      name  age        add
# sn
# 3    Hari   33   Janakpur
# 4   Nabin   66  Kathmandu
# 5   Akash   23  Bhaktapur

# %%
import pandas as pd
df=pd.read_csv('data.csv',index_col="sn")
df.loc[2:5]
# Out:
#      name  age        add   phone
# sn
# 2   Shyam   44  Bhaktapur  789654
# 3    Hari   33   Janakpur  980654
# 4   Nabin   66  Kathmandu  897654
# 5   Akash   23  Bhaktapur  980765

# %%
import pandas as pd
df=pd.read_csv('data.csv',index_col="name")
df["Ram":"Hari"]
# Out:
#        sn  age        add     phone
# name
# Ram     1   23  Kathmandu  98442789
# Shyam   2   44  Bhaktapur    789654
# Hari    3   33   Janakpur    980654

# %%
import pandas as pd
df=pd.read_csv('data.csv')
df[df["name"]=="Ram"]
# Out:
#    sn name  age        add     phone
# 0   1  Ram   23  Kathmandu  98442789

# %%
import pandas as pd
df=pd.read_csv('data.csv')
df[(df["name"]=="Ram")|(df["age"]>40)]
# Out:
#    sn   name  age        add     phone
# 0   1    Ram   23  Kathmandu  98442789
# 1   2  Shyam   44  Bhaktapur    789654
# 3   4  Nabin   66  Kathmandu    897654

# %%
import pandas as pd
df=pd.read_csv('data.csv')
data=df[(df["name"]=="Ram")|(df["age"]>40)]
data.to_csv("new_data.csv")

# %%
import pandas as pd
df=pd.read_csv('data.csv',index_col="name")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, Ram to Nabin
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sn      6 non-null      int64
#  1   age     6 non-null      int64
#  2   add     6 non-null      object
#  3   phone   6 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 240.0+ bytes

# %%
import pandas as pd
df=pd.read_csv('data.csv',index_col="name")
df.describe()
# Out:
#              sn        age         phone
# count  6.000000   6.000000  6.000000e+00
# mean   3.500000  36.833333  1.866134e+07
# std    1.870829  16.265505  3.924897e+07
# min    1.000000  23.000000  7.896540e+05
# 25%    2.250000  25.250000  9.184040e+05
# 50%    3.500000  32.500000  9.807095e+05
# 75%    4.750000  41.250000  7.652566e+06
# max    6.000000  66.000000  9.844279e+07

# %%
# list inside dict
import pandas as pd
data = {'sn':[1,2,3,4,5],
       'name':['Ram','Shyam','Hari','Sabin','Sita']}
df = pd.DataFrame(data)
df.to_csv('new_data.csv')
df
# Out:
#    sn   name
# 0   1    Ram
# 1   2  Shyam
# 2   3   Hari
# 3   4  Sabin
# 4   5   Sita

# %%
df['name']
# Out:
# 0      Ram
# 1    Shyam
# 2     Hari
# 3    Sabin
# 4     Sita
# Name: name, dtype: object

# %%
list(df['name'].values)
# Out:
# ['Ram', 'Shyam', 'Hari', 'Sabin', 'Sita']

# %%
import csv
data = [['sn','name','age'],
       [1,'Akash',34],
       [2,'Nabin',23]]
file = open('info.csv','w')
x = csv.writer(file)
x.writerows(data)
file.close()

# %%
df = pd.read_csv('info.csv')
df
# Out:
#    sn   name  age
# 0   1  Akash   34
# 1   2  Nabin   23

# %%
import csv
csvfile =  open('info.csv')
reader = csv.DictReader(csvfile)
for row in reader:
    print(row)
# Out:
# {'sn': '1', 'name': 'Akash', 'age': '34'}
# {'sn': '2', 'name': 'Nabin', 'age': '23'}

# %%
import csv
csv_columns = ['Name', 'Age', 'Address']
dict = [
    {'Name':'Aayush','Age':23,'Address':'Katmandu'},
    {'Name':'Shyam','Age':33,'Address':'Patan'}
]

csvfile =  open("data.csv", 'w')
writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
writer.writeheader()
writer.writerows(dict)

csvfile.close()

# %%
# list inside dict
import pandas as pd
data = {'sn':[1,2,3,4,5],
       'name':['Ram','Shyam','Hari','Sabin','Sita']}
df = pd.DataFrame(data)
df.to_json('new_data.json')
df
# Out:
#    sn   name
# 0   1    Ram
# 1   2  Shyam
# 2   3   Hari
# 3   4  Sabin
# 4   5   Sita

# %%
df = df.drop(0, axis=0)
df
# Out:
#    sn   name
# 1   2  Shyam
# 2   3   Hari
# 3   4  Sabin
# 4   5   Sita
